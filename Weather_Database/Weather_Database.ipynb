# %%
#Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
#Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
#Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
#Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# %%
#Create a list for holding the cities.
cities = []
#Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    #If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
#Print the city count to confirm sufficient count.
len(cities)
# Out:
# 757

# %%
#Import the requests library.
import requests

#Import the API key.
from config import weather_api_key

# %%
#Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
#Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

#Create counters.
record_count = 1
set_count = 1

#Loop through all the cities in the list.
for i, city in enumerate(cities):

    #Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    #Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    #Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    #Add 1 to the record count.
    record_count += 1

#Run an API request for each of the cities.
    try:
        #Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        #Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_description = [i["description"] for i in city_weather ["weather"]]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        #Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_description})

#If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

#Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | iisalmi
# Processing Record 2 of Set 1 | rikitea
# Processing Record 3 of Set 1 | illapel
# Processing Record 4 of Set 1 | banda aceh
# Processing Record 5 of Set 1 | roma
# Processing Record 6 of Set 1 | brae
# Processing Record 7 of Set 1 | blonduos
# City not found. Skipping...
# Processing Record 8 of Set 1 | vaitupu
# City not found. Skipping...
# Processing Record 9 of Set 1 | port elizabeth
# Processing Record 10 of Set 1 | leningradskiy
# Processing Record 11 of Set 1 | hobart
# Processing Record 12 of Set 1 | chuy
# Processing Record 13 of Set 1 | severo-kurilsk
# Processing Record 14 of Set 1 | sergeyevka
# Processing Record 15 of Set 1 | beringovskiy
# Processing Record 16 of Set 1 | sao filipe
# Processing Record 17 of Set 1 | arraial do cabo
# Processing Record 18 of Set 1 | mackay
# Processing Record 19 of Set 1 | isangel
# Processing Record 20 of Set 1 | kieta
# Processing Record 21 of Set 1 | saskylakh
# Processing Record 22 of Set 1 | lima
# Processing Record 23 of Set 1 | hilo
# Processing Record 24 of Set 1 | lagoa
# Processing Record 25 of Set 1 | bredasdorp
# Processing Record 26 of Set 1 | soke
# Processing Record 27 of Set 1 | ayios matthaios
# City not found. Skipping...
# Processing Record 28 of Set 1 | oistins
# Processing Record 29 of Set 1 | bluff
# Processing Record 30 of Set 1 | dera din panah
# City not found. Skipping...
# Processing Record 31 of Set 1 | yellowknife
# Processing Record 32 of Set 1 | lompoc
# Processing Record 33 of Set 1 | kyren
# Processing Record 34 of Set 1 | nikolskoye
# Processing Record 35 of Set 1 | atuona
# Processing Record 36 of Set 1 | ust-karsk
# Processing Record 37 of Set 1 | talnakh
# Processing Record 38 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 39 of Set 1 | butaritari
# Processing Record 40 of Set 1 | carnarvon
# Processing Record 41 of Set 1 | albany
# Processing Record 42 of Set 1 | salalah
# Processing Record 43 of Set 1 | saint-ambroise
# Processing Record 44 of Set 1 | qaanaaq
# Processing Record 45 of Set 1 | qurayyat
# Processing Record 46 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 47 of Set 1 | mar del plata
# Processing Record 48 of Set 1 | rognan
# Processing Record 49 of Set 1 | yithion
# City not found. Skipping...
# Processing Record 50 of Set 1 | port alfred
# Processing Record 1 of Set 2 | jamestown
# Processing Record 2 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 3 of Set 2 | gravdal
# Processing Record 4 of Set 2 | lata
# Processing Record 5 of Set 2 | ribeira grande
# Processing Record 6 of Set 2 | bethel
# Processing Record 7 of Set 2 | saint-augustin
# Processing Record 8 of Set 2 | iskateley
# Processing Record 9 of Set 2 | gornyak
# Processing Record 10 of Set 2 | kapit
# Processing Record 11 of Set 2 | muros
# Processing Record 12 of Set 2 | punta arenas
# Processing Record 13 of Set 2 | muli
# Processing Record 14 of Set 2 | kattivakkam
# Processing Record 15 of Set 2 | zhigansk
# Processing Record 16 of Set 2 | hithadhoo
# Processing Record 17 of Set 2 | palabuhanratu
# City not found. Skipping...
# Processing Record 18 of Set 2 | saint-philippe
# Processing Record 19 of Set 2 | avarua
# Processing Record 20 of Set 2 | road town
# Processing Record 21 of Set 2 | mataura
# Processing Record 22 of Set 2 | longyearbyen
# Processing Record 23 of Set 2 | iqaluit
# Processing Record 24 of Set 2 | busselton
# Processing Record 25 of Set 2 | ushuaia
# Processing Record 26 of Set 2 | mahebourg
# Processing Record 27 of Set 2 | bengkulu
# Processing Record 28 of Set 2 | vila velha
# Processing Record 29 of Set 2 | sitka
# Processing Record 30 of Set 2 | port hardy
# Processing Record 31 of Set 2 | pisco
# Processing Record 32 of Set 2 | manaure
# Processing Record 33 of Set 2 | narsaq
# Processing Record 34 of Set 2 | cape town
# Processing Record 35 of Set 2 | tarnogskiy gorodok
# Processing Record 36 of Set 2 | kathmandu
# Processing Record 37 of Set 2 | panipat
# Processing Record 38 of Set 2 | dingle
# Processing Record 39 of Set 2 | gornopravdinsk
# Processing Record 40 of Set 2 | stornoway
# Processing Record 41 of Set 2 | gayny
# Processing Record 42 of Set 2 | khatanga
# Processing Record 43 of Set 2 | thompson
# Processing Record 44 of Set 2 | berbera
# Processing Record 45 of Set 2 | portland
# Processing Record 46 of Set 2 | garhi yasin
# Processing Record 47 of Set 2 | kapaa
# Processing Record 48 of Set 2 | jalu
# Processing Record 49 of Set 2 | luena
# Processing Record 50 of Set 2 | nsanje
# Processing Record 1 of Set 3 | sonoita
# Processing Record 2 of Set 3 | gerash
# Processing Record 3 of Set 3 | ponta do sol
# Processing Record 4 of Set 3 | tuktoyaktuk
# Processing Record 5 of Set 3 | upernavik
# Processing Record 6 of Set 3 | bor
# Processing Record 7 of Set 3 | vanderhoof
# Processing Record 8 of Set 3 | kuloy
# Processing Record 9 of Set 3 | tilichiki
# Processing Record 10 of Set 3 | puerto ayora
# Processing Record 11 of Set 3 | vaini
# Processing Record 12 of Set 3 | cayenne
# Processing Record 13 of Set 3 | wexford
# Processing Record 14 of Set 3 | qui nhon
# Processing Record 15 of Set 3 | marzuq
# Processing Record 16 of Set 3 | batagay
# Processing Record 17 of Set 3 | whitianga
# Processing Record 18 of Set 3 | amderma
# City not found. Skipping...
# Processing Record 19 of Set 3 | mareeba
# Processing Record 20 of Set 3 | tasiilaq
# Processing Record 21 of Set 3 | nome
# Processing Record 22 of Set 3 | xining
# Processing Record 23 of Set 3 | puerto varas
# Processing Record 24 of Set 3 | ilulissat
# Processing Record 25 of Set 3 | ostrovnoy
# Processing Record 26 of Set 3 | belushya guba
# City not found. Skipping...
# Processing Record 27 of Set 3 | ogulin
# Processing Record 28 of Set 3 | morgantown
# Processing Record 29 of Set 3 | severnyy
# Processing Record 30 of Set 3 | prince rupert
# Processing Record 31 of Set 3 | hermanus
# Processing Record 32 of Set 3 | lebu
# Processing Record 33 of Set 3 | manado
# Processing Record 34 of Set 3 | haveli
# Processing Record 35 of Set 3 | seoul
# Processing Record 36 of Set 3 | fort nelson
# Processing Record 37 of Set 3 | la serena
# Processing Record 38 of Set 3 | airai
# Processing Record 39 of Set 3 | half moon bay
# Processing Record 40 of Set 3 | tautira
# Processing Record 41 of Set 3 | marabba
# Processing Record 42 of Set 3 | vardo
# Processing Record 43 of Set 3 | marcona
# City not found. Skipping...
# Processing Record 44 of Set 3 | ankang
# Processing Record 45 of Set 3 | guerrero negro
# Processing Record 46 of Set 3 | hasaki
# Processing Record 47 of Set 3 | mildura
# Processing Record 48 of Set 3 | alofi
# Processing Record 49 of Set 3 | la ronge
# Processing Record 50 of Set 3 | plettenberg bay
# Processing Record 1 of Set 4 | lukovetskiy
# Processing Record 2 of Set 4 | souillac
# Processing Record 3 of Set 4 | kruisfontein
# Processing Record 4 of Set 4 | raudeberg
# Processing Record 5 of Set 4 | tsihombe
# City not found. Skipping...
# Processing Record 6 of Set 4 | barrow
# Processing Record 7 of Set 4 | ataco
# Processing Record 8 of Set 4 | aktau
# Processing Record 9 of Set 4 | linkoping
# Processing Record 10 of Set 4 | olafsvik
# Processing Record 11 of Set 4 | nizhniy baskunchak
# Processing Record 12 of Set 4 | qaqortoq
# Processing Record 13 of Set 4 | new norfolk
# Processing Record 14 of Set 4 | waipawa
# Processing Record 15 of Set 4 | vao
# Processing Record 16 of Set 4 | praia da vitoria
# Processing Record 17 of Set 4 | fuente de oro
# Processing Record 18 of Set 4 | castro
# Processing Record 19 of Set 4 | marinette
# Processing Record 20 of Set 4 | mys shmidta
# City not found. Skipping...
# Processing Record 21 of Set 4 | amapa
# Processing Record 22 of Set 4 | cairns
# Processing Record 23 of Set 4 | beloha
# Processing Record 24 of Set 4 | san cristobal
# Processing Record 25 of Set 4 | kuruman
# Processing Record 26 of Set 4 | constitucion
# Processing Record 27 of Set 4 | hualmay
# Processing Record 28 of Set 4 | byron bay
# Processing Record 29 of Set 4 | codrington
# Processing Record 30 of Set 4 | pochutla
# Processing Record 31 of Set 4 | cabo san lucas
# Processing Record 32 of Set 4 | eppingen
# Processing Record 33 of Set 4 | grand gaube
# Processing Record 34 of Set 4 | esperance
# Processing Record 35 of Set 4 | balkanabat
# Processing Record 36 of Set 4 | aromashevo
# Processing Record 37 of Set 4 | bayan
# Processing Record 38 of Set 4 | grants pass
# Processing Record 39 of Set 4 | buhe
# Processing Record 40 of Set 4 | babushkin
# Processing Record 41 of Set 4 | maldonado
# Processing Record 42 of Set 4 | kizema
# Processing Record 43 of Set 4 | moose factory
# Processing Record 44 of Set 4 | balkhash
# Processing Record 45 of Set 4 | mount gambier
# Processing Record 46 of Set 4 | louisbourg
# City not found. Skipping...
# Processing Record 47 of Set 4 | lais
# Processing Record 48 of Set 4 | shadrinsk
# Processing Record 49 of Set 4 | srednekolymsk
# Processing Record 50 of Set 4 | teguise
# Processing Record 1 of Set 5 | novyye burasy
# Processing Record 2 of Set 5 | melo
# Processing Record 3 of Set 5 | nouadhibou
# Processing Record 4 of Set 5 | hamilton
# Processing Record 5 of Set 5 | mnogovershinnyy
# Processing Record 6 of Set 5 | paranga
# Processing Record 7 of Set 5 | vanavara
# Processing Record 8 of Set 5 | korla
# Processing Record 9 of Set 5 | maun
# Processing Record 10 of Set 5 | saint george
# Processing Record 11 of Set 5 | lucea
# Processing Record 12 of Set 5 | mandiana
# Processing Record 13 of Set 5 | port lincoln
# Processing Record 14 of Set 5 | balikpapan
# Processing Record 15 of Set 5 | nanzhou
# Processing Record 16 of Set 5 | georgetown
# Processing Record 17 of Set 5 | san quintin
# Processing Record 18 of Set 5 | hun
# Processing Record 19 of Set 5 | zambezi
# Processing Record 20 of Set 5 | east london
# Processing Record 21 of Set 5 | sorong
# Processing Record 22 of Set 5 | sulangan
# Processing Record 23 of Set 5 | nizhniy kuranakh
# Processing Record 24 of Set 5 | zhigalovo
# Processing Record 25 of Set 5 | nanakuli
# Processing Record 26 of Set 5 | saldanha
# Processing Record 27 of Set 5 | tuatapere
# Processing Record 28 of Set 5 | riberalta
# Processing Record 29 of Set 5 | san policarpo
# Processing Record 30 of Set 5 | opuwo
# Processing Record 31 of Set 5 | flagstaff
# Processing Record 32 of Set 5 | rawson
# Processing Record 33 of Set 5 | cherskiy
# Processing Record 34 of Set 5 | dikson
# Processing Record 35 of Set 5 | puerto leguizamo
# Processing Record 36 of Set 5 | broome
# Processing Record 37 of Set 5 | chagda
# City not found. Skipping...
# Processing Record 38 of Set 5 | rawannawi
# City not found. Skipping...
# Processing Record 39 of Set 5 | touros
# Processing Record 40 of Set 5 | ballina
# Processing Record 41 of Set 5 | sola
# Processing Record 42 of Set 5 | general roca
# Processing Record 43 of Set 5 | hami
# Processing Record 44 of Set 5 | juifang
# City not found. Skipping...
# Processing Record 45 of Set 5 | nanortalik
# Processing Record 46 of Set 5 | pangnirtung
# Processing Record 47 of Set 5 | fairbanks
# Processing Record 48 of Set 5 | kyrylivka
# Processing Record 49 of Set 5 | samarai
# Processing Record 50 of Set 5 | bocaranga
# City not found. Skipping...
# Processing Record 1 of Set 6 | zafra
# Processing Record 2 of Set 6 | grindavik
# Processing Record 3 of Set 6 | el alto
# Processing Record 4 of Set 6 | kismayo
# Processing Record 5 of Set 6 | bolungarvik
# City not found. Skipping...
# Processing Record 6 of Set 6 | mehamn
# Processing Record 7 of Set 6 | porto novo
# Processing Record 8 of Set 6 | sur
# Processing Record 9 of Set 6 | barentu
# Processing Record 10 of Set 6 | berlevag
# Processing Record 11 of Set 6 | pombas
# Processing Record 12 of Set 6 | taoudenni
# Processing Record 13 of Set 6 | kralendijk
# Processing Record 14 of Set 6 | orange cove
# Processing Record 15 of Set 6 | ola
# Processing Record 16 of Set 6 | cockburn town
# Processing Record 17 of Set 6 | chernyshevskiy
# Processing Record 18 of Set 6 | wajima
# Processing Record 19 of Set 6 | razam
# Processing Record 20 of Set 6 | maltahohe
# Processing Record 21 of Set 6 | hashtgerd
# Processing Record 22 of Set 6 | faya
# Processing Record 23 of Set 6 | katsuura
# Processing Record 24 of Set 6 | yar-sale
# Processing Record 25 of Set 6 | dwarka
# Processing Record 26 of Set 6 | krasnoselkup
# Processing Record 27 of Set 6 | lander
# Processing Record 28 of Set 6 | ribas do rio pardo
# Processing Record 29 of Set 6 | asyut
# Processing Record 30 of Set 6 | eidsvag
# Processing Record 31 of Set 6 | troitskoye
# Processing Record 32 of Set 6 | ipaussu
# Processing Record 33 of Set 6 | kasongo-lunda
# Processing Record 34 of Set 6 | ko samui
# Processing Record 35 of Set 6 | ardesen
# Processing Record 36 of Set 6 | alta gracia
# Processing Record 37 of Set 6 | sakhon nakhon
# Processing Record 38 of Set 6 | sanming
# Processing Record 39 of Set 6 | chapais
# Processing Record 40 of Set 6 | veere
# Processing Record 41 of Set 6 | barkly west
# Processing Record 42 of Set 6 | fairlie
# Processing Record 43 of Set 6 | tabuk
# Processing Record 44 of Set 6 | talusan
# Processing Record 45 of Set 6 | norman wells
# Processing Record 46 of Set 6 | nizhneyansk
# City not found. Skipping...
# Processing Record 47 of Set 6 | guarapari
# Processing Record 48 of Set 6 | payson
# Processing Record 49 of Set 6 | amot
# Processing Record 50 of Set 6 | flin flon
# Processing Record 1 of Set 7 | coahuayana
# Processing Record 2 of Set 7 | ishigaki
# Processing Record 3 of Set 7 | angoche
# Processing Record 4 of Set 7 | eydhafushi
# Processing Record 5 of Set 7 | lolua
# City not found. Skipping...
# Processing Record 6 of Set 7 | bargal
# City not found. Skipping...
# Processing Record 7 of Set 7 | les escoumins
# Processing Record 8 of Set 7 | kinshasa
# Processing Record 9 of Set 7 | yanggu
# Processing Record 10 of Set 7 | torbay
# Processing Record 11 of Set 7 | kapoeta
# Processing Record 12 of Set 7 | saint-joseph
# Processing Record 13 of Set 7 | makakilo city
# Processing Record 14 of Set 7 | kidal
# Processing Record 15 of Set 7 | rabo de peixe
# Processing Record 16 of Set 7 | hargeysa
# Processing Record 17 of Set 7 | coquimbo
# Processing Record 18 of Set 7 | waingapu
# Processing Record 19 of Set 7 | aflu
# City not found. Skipping...
# Processing Record 20 of Set 7 | birin
# Processing Record 21 of Set 7 | lodja
# Processing Record 22 of Set 7 | mabaruma
# Processing Record 23 of Set 7 | fortuna
# Processing Record 24 of Set 7 | sinnamary
# Processing Record 25 of Set 7 | san patricio
# Processing Record 26 of Set 7 | astoria
# Processing Record 27 of Set 7 | maniitsoq
# Processing Record 28 of Set 7 | shnogh
# Processing Record 29 of Set 7 | de aar
# Processing Record 30 of Set 7 | college
# Processing Record 31 of Set 7 | galesong
# Processing Record 32 of Set 7 | lasa
# Processing Record 33 of Set 7 | broken hill
# Processing Record 34 of Set 7 | aswan
# Processing Record 35 of Set 7 | odienne
# Processing Record 36 of Set 7 | meulaboh
# Processing Record 37 of Set 7 | ternate
# Processing Record 38 of Set 7 | vila franca do campo
# Processing Record 39 of Set 7 | jiwani
# Processing Record 40 of Set 7 | barcelona
# Processing Record 41 of Set 7 | nynashamn
# Processing Record 42 of Set 7 | port-gentil
# Processing Record 43 of Set 7 | hit
# Processing Record 44 of Set 7 | panaba
# Processing Record 45 of Set 7 | eslamshahr
# Processing Record 46 of Set 7 | lahaina
# Processing Record 47 of Set 7 | karkaralinsk
# City not found. Skipping...
# Processing Record 48 of Set 7 | umm lajj
# Processing Record 49 of Set 7 | cidreira
# Processing Record 50 of Set 7 | moerai
# Processing Record 1 of Set 8 | margate
# Processing Record 2 of Set 8 | diamantino
# Processing Record 3 of Set 8 | ust-tsilma
# Processing Record 4 of Set 8 | eureka
# Processing Record 5 of Set 8 | soe
# Processing Record 6 of Set 8 | wendo
# Processing Record 7 of Set 8 | gamba
# Processing Record 8 of Set 8 | lavrentiya
# Processing Record 9 of Set 8 | ures
# Processing Record 10 of Set 8 | saryshagan
# City not found. Skipping...
# Processing Record 11 of Set 8 | kosino
# Processing Record 12 of Set 8 | paamiut
# Processing Record 13 of Set 8 | solano
# Processing Record 14 of Set 8 | deputatskiy
# Processing Record 15 of Set 8 | koslan
# Processing Record 16 of Set 8 | kavaratti
# Processing Record 17 of Set 8 | laguna
# Processing Record 18 of Set 8 | naberera
# Processing Record 19 of Set 8 | bukama
# Processing Record 20 of Set 8 | kaohsiung
# Processing Record 21 of Set 8 | coihueco
# Processing Record 22 of Set 8 | alotau
# City not found. Skipping...
# Processing Record 23 of Set 8 | ahipara
# Processing Record 24 of Set 8 | ngunguru
# Processing Record 25 of Set 8 | te anau
# Processing Record 26 of Set 8 | kahului
# Processing Record 27 of Set 8 | sinkat
# City not found. Skipping...
# Processing Record 28 of Set 8 | ous
# Processing Record 29 of Set 8 | egvekinot
# Processing Record 30 of Set 8 | camacha
# Processing Record 31 of Set 8 | rio grande
# Processing Record 32 of Set 8 | natal
# Processing Record 33 of Set 8 | port macquarie
# Processing Record 34 of Set 8 | chokurdakh
# Processing Record 35 of Set 8 | goderich
# Processing Record 36 of Set 8 | victoria
# Processing Record 37 of Set 8 | korem
# Processing Record 38 of Set 8 | amurrio
# Processing Record 39 of Set 8 | khuzhir
# Processing Record 40 of Set 8 | bayir
# Processing Record 41 of Set 8 | tiksi
# Processing Record 42 of Set 8 | flinders
# Processing Record 43 of Set 8 | los llanos de aridane
# Processing Record 44 of Set 8 | bemidji
# Processing Record 45 of Set 8 | realeza
# Processing Record 46 of Set 8 | buala
# Processing Record 47 of Set 8 | eregli
# Processing Record 48 of Set 8 | finschhafen
# Processing Record 49 of Set 8 | florianopolis
# Processing Record 50 of Set 8 | rach gia
# Processing Record 1 of Set 9 | tucumcari
# Processing Record 2 of Set 9 | husavik
# Processing Record 3 of Set 9 | myitkyina
# Processing Record 4 of Set 9 | ulladulla
# Processing Record 5 of Set 9 | oranjestad
# Processing Record 6 of Set 9 | biak
# Processing Record 7 of Set 9 | dumas
# Processing Record 8 of Set 9 | jujuy
# City not found. Skipping...
# Processing Record 9 of Set 9 | aklavik
# Processing Record 10 of Set 9 | orizona
# Processing Record 11 of Set 9 | katangli
# Processing Record 12 of Set 9 | geraldton
# Processing Record 13 of Set 9 | antofagasta
# Processing Record 14 of Set 9 | champerico
# Processing Record 15 of Set 9 | rosetta
# Processing Record 16 of Set 9 | pozo colorado
# Processing Record 17 of Set 9 | glace bay
# Processing Record 18 of Set 9 | neiafu
# Processing Record 19 of Set 9 | alta floresta
# Processing Record 20 of Set 9 | rundu
# Processing Record 21 of Set 9 | shagonar
# Processing Record 22 of Set 9 | krasnoye
# Processing Record 23 of Set 9 | mehran
# Processing Record 24 of Set 9 | etchoropo
# Processing Record 25 of Set 9 | binzhou
# Processing Record 26 of Set 9 | lokosovo
# Processing Record 27 of Set 9 | chimbote
# Processing Record 28 of Set 9 | grand river south east
# City not found. Skipping...
# Processing Record 29 of Set 9 | mananjary
# Processing Record 30 of Set 9 | at-bashi
# Processing Record 31 of Set 9 | puerto boyaca
# Processing Record 32 of Set 9 | penukonda
# Processing Record 33 of Set 9 | kloulklubed
# Processing Record 34 of Set 9 | canton
# Processing Record 35 of Set 9 | ponta delgada
# Processing Record 36 of Set 9 | gat
# Processing Record 37 of Set 9 | kulhudhuffushi
# Processing Record 38 of Set 9 | baihar
# Processing Record 39 of Set 9 | noumea
# Processing Record 40 of Set 9 | ozinki
# Processing Record 41 of Set 9 | ballstad
# City not found. Skipping...
# Processing Record 42 of Set 9 | basco
# Processing Record 43 of Set 9 | alim
# Processing Record 44 of Set 9 | rungata
# City not found. Skipping...
# Processing Record 45 of Set 9 | torgau
# Processing Record 46 of Set 9 | seymchan
# Processing Record 47 of Set 9 | daru
# Processing Record 48 of Set 9 | sobolevo
# Processing Record 49 of Set 9 | tumannyy
# City not found. Skipping...
# Processing Record 50 of Set 9 | omsukchan
# Processing Record 1 of Set 10 | kodiak
# Processing Record 2 of Set 10 | adre
# Processing Record 3 of Set 10 | sentyabrskiy
# City not found. Skipping...
# Processing Record 4 of Set 10 | coihaique
# Processing Record 5 of Set 10 | ruatoria
# City not found. Skipping...
# Processing Record 6 of Set 10 | voyvozh
# Processing Record 7 of Set 10 | tezu
# Processing Record 8 of Set 10 | olinda
# Processing Record 9 of Set 10 | qasigiannguit
# Processing Record 10 of Set 10 | morondava
# Processing Record 11 of Set 10 | stonewall
# Processing Record 12 of Set 10 | clemson
# Processing Record 13 of Set 10 | attawapiskat
# City not found. Skipping...
# Processing Record 14 of Set 10 | port blair
# Processing Record 15 of Set 10 | newport
# Processing Record 16 of Set 10 | palmer
# Processing Record 17 of Set 10 | jinsha
# Processing Record 18 of Set 10 | yopal
# Processing Record 19 of Set 10 | korcula
# Processing Record 20 of Set 10 | channel-port aux basques
# Processing Record 21 of Set 10 | luderitz
# Processing Record 22 of Set 10 | camana
# Processing Record 23 of Set 10 | susangerd
# Processing Record 24 of Set 10 | faanui
# Processing Record 25 of Set 10 | mezen
# Processing Record 26 of Set 10 | celestun
# Processing Record 27 of Set 10 | avera
# Processing Record 28 of Set 10 | manzanillo
# Processing Record 29 of Set 10 | bilma
# Processing Record 30 of Set 10 | alyangula
# Processing Record 31 of Set 10 | alice springs
# Processing Record 32 of Set 10 | pevek
# Processing Record 33 of Set 10 | longfeng
# Processing Record 34 of Set 10 | chicama
# Processing Record 35 of Set 10 | wamba
# Processing Record 36 of Set 10 | san antonio
# Processing Record 37 of Set 10 | petropavlovsk-kamchatskiy
# Processing Record 38 of Set 10 | kikwit
# Processing Record 39 of Set 10 | santa cruz de la palma
# Processing Record 40 of Set 10 | buenaventura
# Processing Record 41 of Set 10 | tura
# Processing Record 42 of Set 10 | martapura
# Processing Record 43 of Set 10 | hinton
# Processing Record 44 of Set 10 | silifke
# Processing Record 45 of Set 10 | sawakin
# Processing Record 46 of Set 10 | tabiauea
# City not found. Skipping...
# Processing Record 47 of Set 10 | launceston
# Processing Record 48 of Set 10 | tamandare
# Processing Record 49 of Set 10 | khandyga
# Processing Record 50 of Set 10 | uarini
# Processing Record 1 of Set 11 | tagusao
# Processing Record 2 of Set 11 | loding
# Processing Record 3 of Set 11 | rantauprapat
# Processing Record 4 of Set 11 | condado
# Processing Record 5 of Set 11 | ombessa
# Processing Record 6 of Set 11 | verkhoyansk
# Processing Record 7 of Set 11 | kitui
# Processing Record 8 of Set 11 | pangoa
# Processing Record 9 of Set 11 | bundaberg
# Processing Record 10 of Set 11 | bilibino
# Processing Record 11 of Set 11 | lorengau
# Processing Record 12 of Set 11 | kursk
# Processing Record 13 of Set 11 | kavieng
# Processing Record 14 of Set 11 | hovd
# Processing Record 15 of Set 11 | provideniya
# Processing Record 16 of Set 11 | bismil
# Processing Record 17 of Set 11 | huitan
# Processing Record 18 of Set 11 | yanan
# City not found. Skipping...
# Processing Record 19 of Set 11 | gorontalo
# Processing Record 20 of Set 11 | linguere
# Processing Record 21 of Set 11 | yulara
# Processing Record 22 of Set 11 | ler
# Processing Record 23 of Set 11 | shakhtinsk
# Processing Record 24 of Set 11 | mayo
# Processing Record 25 of Set 11 | solnechnyy
# Processing Record 26 of Set 11 | shingu
# Processing Record 27 of Set 11 | tessalit
# Processing Record 28 of Set 11 | sherman
# Processing Record 29 of Set 11 | rio gallegos
# Processing Record 30 of Set 11 | ngukurr
# City not found. Skipping...
# Processing Record 31 of Set 11 | kamenka
# Processing Record 32 of Set 11 | aykhal
# Processing Record 33 of Set 11 | saint-pierre
# Processing Record 34 of Set 11 | hagerstown
# Processing Record 35 of Set 11 | sunrise manor
# Processing Record 36 of Set 11 | bathsheba
# Processing Record 37 of Set 11 | inirida
# Processing Record 38 of Set 11 | alihe
# Processing Record 39 of Set 11 | vredendal
# Processing Record 40 of Set 11 | zlobin
# Processing Record 41 of Set 11 | dandong
# Processing Record 42 of Set 11 | sylacauga
# Processing Record 43 of Set 11 | yumen
# Processing Record 44 of Set 11 | arawa
# Processing Record 45 of Set 11 | dudinka
# Processing Record 46 of Set 11 | yol
# Processing Record 47 of Set 11 | baykit
# Processing Record 48 of Set 11 | ironton
# Processing Record 49 of Set 11 | kayerkan
# Processing Record 50 of Set 11 | sao joao da barra
# Processing Record 1 of Set 12 | smidovich
# Processing Record 2 of Set 12 | pizarro
# Processing Record 3 of Set 12 | tuggurt
# City not found. Skipping...
# Processing Record 4 of Set 12 | ixtapa
# Processing Record 5 of Set 12 | formoso do araguaia
# City not found. Skipping...
# Processing Record 6 of Set 12 | moron
# Processing Record 7 of Set 12 | boende
# Processing Record 8 of Set 12 | westport
# Processing Record 9 of Set 12 | aras
# Processing Record 10 of Set 12 | ossora
# Processing Record 11 of Set 12 | boca do acre
# Processing Record 12 of Set 12 | hambantota
# Processing Record 13 of Set 12 | puerto baquerizo moreno
# Processing Record 14 of Set 12 | birobidzhan
# Processing Record 15 of Set 12 | bend
# Processing Record 16 of Set 12 | solovetskiy
# City not found. Skipping...
# Processing Record 17 of Set 12 | acari
# Processing Record 18 of Set 12 | abu jubayhah
# City not found. Skipping...
# Processing Record 19 of Set 12 | haibowan
# City not found. Skipping...
# Processing Record 20 of Set 12 | phangnga
# Processing Record 21 of Set 12 | naze
# Processing Record 22 of Set 12 | worland
# Processing Record 23 of Set 12 | lovozero
# Processing Record 24 of Set 12 | raipur
# Processing Record 25 of Set 12 | tashla
# Processing Record 26 of Set 12 | bandarbeyla
# Processing Record 27 of Set 12 | arlit
# Processing Record 28 of Set 12 | auki
# Processing Record 29 of Set 12 | malente
# Processing Record 30 of Set 12 | urdzhar
# City not found. Skipping...
# Processing Record 31 of Set 12 | zabaykalsk
# Processing Record 32 of Set 12 | fort-shevchenko
# Processing Record 33 of Set 12 | carutapera
# Processing Record 34 of Set 12 | pacifica
# Processing Record 35 of Set 12 | kadykchan
# City not found. Skipping...
# Processing Record 36 of Set 12 | vestmannaeyjar
# Processing Record 37 of Set 12 | asmara
# Processing Record 38 of Set 12 | hobyo
# Processing Record 39 of Set 12 | komagane
# Processing Record 40 of Set 12 | copiapo
# Processing Record 41 of Set 12 | zatoka
# Processing Record 42 of Set 12 | piterka
# Processing Record 43 of Set 12 | chambishi
# Processing Record 44 of Set 12 | podyuga
# Processing Record 45 of Set 12 | port said
# Processing Record 46 of Set 12 | nishihara
# Processing Record 47 of Set 12 | kemijarvi
# Processing Record 48 of Set 12 | lengshuitan
# Processing Record 49 of Set 12 | akhalgori
# Processing Record 50 of Set 12 | aksarka
# Processing Record 1 of Set 13 | karpathos
# Processing Record 2 of Set 13 | okhotsk
# Processing Record 3 of Set 13 | ageyevo
# Processing Record 4 of Set 13 | inta
# Processing Record 5 of Set 13 | klaksvik
# Processing Record 6 of Set 13 | saint anthony
# Processing Record 7 of Set 13 | sibolga
# Processing Record 8 of Set 13 | shar
# Processing Record 9 of Set 13 | manjeshwar
# Processing Record 10 of Set 13 | mae hong son
# Processing Record 11 of Set 13 | sivaki
# Processing Record 12 of Set 13 | kushmurun
# Processing Record 13 of Set 13 | san rafael
# Processing Record 14 of Set 13 | san juan
# Processing Record 15 of Set 13 | bima
# Processing Record 16 of Set 13 | araripina
# Processing Record 17 of Set 13 | marystown
# Processing Record 18 of Set 13 | saleaula
# City not found. Skipping...
# Processing Record 19 of Set 13 | gdov
# Processing Record 20 of Set 13 | midlothian
# Processing Record 21 of Set 13 | hanyang
# Processing Record 22 of Set 13 | harnosand
# Processing Record 23 of Set 13 | dorchester
# Processing Record 24 of Set 13 | baruun-urt
# Processing Record 25 of Set 13 | buqayq
# City not found. Skipping...
# Processing Record 26 of Set 13 | kargil
# Processing Record 27 of Set 13 | dongying
# Processing Record 28 of Set 13 | tateyama
# Processing Record 29 of Set 13 | eyl
# Processing Record 30 of Set 13 | cervo
# Processing Record 31 of Set 13 | okoneshnikovo
# Processing Record 32 of Set 13 | hervey bay
# Processing Record 33 of Set 13 | karratha
# Processing Record 34 of Set 13 | ilebo
# Processing Record 35 of Set 13 | tsalka
# Processing Record 36 of Set 13 | bocana de paiwas
# Processing Record 37 of Set 13 | vanimo
# Processing Record 38 of Set 13 | galesburg
# Processing Record 39 of Set 13 | cleethorpes
# Processing Record 40 of Set 13 | diffa
# Processing Record 41 of Set 13 | bull savanna
# Processing Record 42 of Set 13 | nambucca heads
# Processing Record 43 of Set 13 | batemans bay
# Processing Record 44 of Set 13 | saint-paul
# Processing Record 45 of Set 13 | tucuman
# Processing Record 46 of Set 13 | sarahan
# Processing Record 47 of Set 13 | starotitarovskaya
# Processing Record 48 of Set 13 | ormara
# Processing Record 49 of Set 13 | rio branco
# Processing Record 50 of Set 13 | tefe
# Processing Record 1 of Set 14 | kathu
# Processing Record 2 of Set 14 | maragogi
# Processing Record 3 of Set 14 | batagay-alyta
# Processing Record 4 of Set 14 | robertsport
# Processing Record 5 of Set 14 | anadyr
# Processing Record 6 of Set 14 | sambava
# Processing Record 7 of Set 14 | pytalovo
# Processing Record 8 of Set 14 | adrar
# Processing Record 9 of Set 14 | grass valley
# Processing Record 10 of Set 14 | bambous virieux
# Processing Record 11 of Set 14 | uzhur
# Processing Record 12 of Set 14 | pula
# Processing Record 13 of Set 14 | puro
# Processing Record 14 of Set 14 | chokwe
# Processing Record 15 of Set 14 | buluang
# Processing Record 16 of Set 14 | teya
# Processing Record 17 of Set 14 | otradnoye
# Processing Record 18 of Set 14 | cheuskiny
# City not found. Skipping...
# Processing Record 19 of Set 14 | san roque
# Processing Record 20 of Set 14 | araouane
# Processing Record 21 of Set 14 | yichang
# Processing Record 22 of Set 14 | derzhavinsk
# Processing Record 23 of Set 14 | temiscaming
# Processing Record 24 of Set 14 | marrakesh
# Processing Record 25 of Set 14 | cecava
# Processing Record 26 of Set 14 | naron
# Processing Record 27 of Set 14 | hokitika
# Processing Record 28 of Set 14 | kirakira
# Processing Record 29 of Set 14 | darhan
# Processing Record 30 of Set 14 | acajutla
# Processing Record 31 of Set 14 | shelbyville
# Processing Record 32 of Set 14 | kununurra
# Processing Record 33 of Set 14 | jiddah
# City not found. Skipping...
# Processing Record 34 of Set 14 | issoire
# Processing Record 35 of Set 14 | padre bernardo
# Processing Record 36 of Set 14 | arman
# Processing Record 37 of Set 14 | katherine
# Processing Record 38 of Set 14 | charagua
# Processing Record 39 of Set 14 | karaul
# City not found. Skipping...
# Processing Record 40 of Set 14 | saint-felicien
# Processing Record 41 of Set 14 | tiznit
# Processing Record 42 of Set 14 | jumla
# Processing Record 43 of Set 14 | nchelenge
# Processing Record 44 of Set 14 | joensuu
# Processing Record 45 of Set 14 | mantua
# Processing Record 46 of Set 14 | acuna
# City not found. Skipping...
# Processing Record 47 of Set 14 | great falls
# Processing Record 48 of Set 14 | coari
# Processing Record 49 of Set 14 | buchanan
# Processing Record 50 of Set 14 | henties bay
# Processing Record 1 of Set 15 | pangody
# Processing Record 2 of Set 15 | maumere
# Processing Record 3 of Set 15 | clyde river
# Processing Record 4 of Set 15 | rock sound
# Processing Record 5 of Set 15 | portobelo
# Processing Record 6 of Set 15 | hirara
# Processing Record 7 of Set 15 | vilcun
# Processing Record 8 of Set 15 | reconquista
# Processing Record 9 of Set 15 | we
# City not found. Skipping...
# Processing Record 10 of Set 15 | hihifo
# City not found. Skipping...
# Processing Record 11 of Set 15 | cerro san antonio
# City not found. Skipping...
# Processing Record 12 of Set 15 | srivardhan
# Processing Record 13 of Set 15 | manica
# Processing Record 14 of Set 15 | paita
# Processing Record 15 of Set 15 | ajaccio
# Processing Record 16 of Set 15 | karauzyak
# City not found. Skipping...
# Processing Record 17 of Set 15 | houma
# Processing Record 18 of Set 15 | wencheng
# Processing Record 19 of Set 15 | nhulunbuy
# Processing Record 20 of Set 15 | zyryanka
# Processing Record 21 of Set 15 | pecos
# Processing Record 22 of Set 15 | necochea
# Processing Record 23 of Set 15 | orangeburg
# Processing Record 24 of Set 15 | boddam
# Processing Record 25 of Set 15 | gao
# Processing Record 26 of Set 15 | kaitangata
# Processing Record 27 of Set 15 | smithers
# Processing Record 28 of Set 15 | phan rang
# City not found. Skipping...
# Processing Record 29 of Set 15 | galgani
# City not found. Skipping...
# Processing Record 30 of Set 15 | anar darreh
# City not found. Skipping...
# Processing Record 31 of Set 15 | fredericton
# Processing Record 32 of Set 15 | presidencia roque saenz pena
# Processing Record 33 of Set 15 | blantyre
# Processing Record 34 of Set 15 | haines junction
# Processing Record 35 of Set 15 | orzhytsya
# Processing Record 36 of Set 15 | canutama
# Processing Record 37 of Set 15 | kodinsk
# Processing Record 38 of Set 15 | kungurtug
# Processing Record 39 of Set 15 | semey
# Processing Record 40 of Set 15 | lazarev
# Processing Record 41 of Set 15 | skovorodino
# Processing Record 42 of Set 15 | kazalinsk
# City not found. Skipping...
# Processing Record 43 of Set 15 | yining
# Processing Record 44 of Set 15 | woodward
# Processing Record 45 of Set 15 | tazovskiy
# Processing Record 46 of Set 15 | muriwai beach
# Processing Record 47 of Set 15 | puri
# Processing Record 48 of Set 15 | khislavichi
# Processing Record 49 of Set 15 | santa rosa
# Processing Record 50 of Set 15 | rauma
# Processing Record 1 of Set 16 | qandala
# Processing Record 2 of Set 16 | tayu
# Processing Record 3 of Set 16 | mount isa
# Processing Record 4 of Set 16 | takhatpur
# Processing Record 5 of Set 16 | williams lake
# Processing Record 6 of Set 16 | bataipora
# Processing Record 7 of Set 16 | providencia
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
#Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#              City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0         Iisalmi      FI  63.5592   27.1907     41.00        60           0
# 1         Rikitea      PF -23.1203 -134.9692     77.09        68         100
# 2         Illapel      CL -31.6308  -71.1653     76.06        45          14
# 3      Banda Aceh      ID   5.5577   95.3222     79.74        78          63
# 4            Roma      US  43.2128  -75.4557     53.01        50          90
# 5            Brae      GB  60.3964   -1.3530     44.60        81           0
# 6  Port Elizabeth      ZA -33.9180   25.5701     66.20        77           0
# 7   Leningradskiy      RU  69.3833  178.4167     29.77        87         100
# 8          Hobart      AU -42.8794  147.3294     55.40        62          70
# 9            Chuy      UY -33.6971  -53.4616     71.37        66           0
#
#    Wind Speed Current Description
# 0        3.44         [clear sky]
# 1        8.86   [overcast clouds]
# 2        8.50        [few clouds]
# 3        5.19     [broken clouds]
# 4        4.61   [overcast clouds]
# 5       18.41         [clear sky]
# 6        9.22         [clear sky]
# 7        9.44   [overcast clouds]
# 8       16.11     [broken clouds]
# 9        7.76         [clear sky]

# %%
#Create the output file (CSV).
output_data_file = "Weather_Database/WeatherPy_Database.csv"
#Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
